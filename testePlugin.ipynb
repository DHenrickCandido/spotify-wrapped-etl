# %%
import sqlalchemy
import pandas as pd 
from sqlalchemy.orm import sessionmaker
import requests
import json
import pytz
from google.cloud import storage

from datetime import datetime
import datetime
import sqlite3

TOKEN = "BQDhtsEjnQo0QI18tf0goYo5hUCiInbung5T0LAT1Ky5L9ViG7T6stvk-7iJcpl4OXwePIjqFB5q0C0U6hARbT3mQhtrUoD5gwAtup3uD4etxsfjon5C-_QXbnNNnpahhyrDT5BnEdDKrEFRb7RnBKowgxDmPHk1NIH_qTWbLbGUEn0hdQjIPUEwmOmCFpH-CxEWK7aJdA"

def process_payload(payload_to_process):
    dt_insercao = create_dt_insercao()
    df = pd.DataFrame()
    df['track'] = payload_to_process['track']
    df['played_at'] = payload_to_process['played_at']
    df['context'] = payload_to_process['context']
    df['partition'] = dt_insercao[:13]

    print(payload_to_process['played_at'])
    #continuar com base no process_payload to projeto api
def create_dt_insercao():
    insertion_date = datetime.datetime.utcnow().replace(tzinfo=pytz.UTC)
    insertion_date = insertion_date.astimezone(pytz.timezone("America/Sao_Paulo"))
    return str(insertion_date)[:26]  # cut out the -3:00 timezone information

if __name__ == "__main__":

    headers = {
        "Accept": "application/json",
        "Content-Type": "application/json",
        "Authorization": "Bearer {token}".format(token=TOKEN)
    }

    today = datetime.datetime.now()
    yesterday = today - datetime.timedelta(days=1)
    yesterday_unix_timestamp = int(yesterday.timestamp()) * 1000

    r = requests.get('https://api.spotify.com/v1/me/player/recently-played?limit=2&after={time}'.format(time=yesterday_unix_timestamp), headers = headers)

    data = r.json()
    

    items = data["items"]

    # print(len(items))
    # print(payloads)


    process_payload(items[0])

# %%
# !pip install chardet
# Out:
# Traceback (most recent call last):
#   File "/home/kitinclusivotpta/anaconda3/bin/pip", line 7, in <module>
#     from pip._internal.cli.main import main
#   File "/home/kitinclusivotpta/anaconda3/lib/python3.5/site-packages/pip/_internal/cli/main.py", line 57
#     sys.stderr.write(f"ERROR: {exc}")
#                                    ^
# SyntaxError: invalid syntax

# %%
# !pip install google-cloud-storage
# Out:
# Collecting google-cloud-storage
#   Using cached google_cloud_storage-2.7.0-py2.py3-none-any.whl (110 kB)
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5
#   Using cached google_api_core-2.11.0-py3-none-any.whl (120 kB)
# Collecting google-auth<3.0dev,>=1.25.0
#   Using cached google_auth-2.16.1-py2.py3-none-any.whl (177 kB)
# Collecting google-resumable-media>=2.3.2
#   Using cached google_resumable_media-2.4.1-py2.py3-none-any.whl (77 kB)
# Collecting google-cloud-core<3.0dev,>=2.3.0
#   Using cached google_cloud_core-2.3.2-py2.py3-none-any.whl (29 kB)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /home/kitinclusivotpta/anaconda3/lib/python3.7/site-packages (from google-cloud-storage) (2.22.0)
# Collecting protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5
#   Downloading protobuf-4.22.0-cp37-abi3-manylinux2014_x86_64.whl (302 kB)
#      |████████████████████████████████| 302 kB 4.2 MB/s eta 0:00:01
# Collecting googleapis-common-protos<2.0dev,>=1.56.2
#   Using cached googleapis_common_protos-1.58.0-py2.py3-none-any.whl (223 kB)
# Requirement already satisfied: six>=1.9.0 in /home/kitinclusivotpta/anaconda3/lib/python3.7/site-packages (from google-auth<3.0dev,>=1.25.0->google-cloud-storage) (1.14.0)
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Using cached cachetools-5.3.0-py3-none-any.whl (9.3 kB)
# Collecting rsa<5,>=3.1.4; python_version >= "3.6"
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting google-crc32c<2.0dev,>=1.0
#   Downloading google_crc32c-1.5.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (32 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /home/kitinclusivotpta/anaconda3/lib/python3.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (2019.11.28)
# Requirement already satisfied: idna<2.9,>=2.5 in /home/kitinclusivotpta/anaconda3/lib/python3.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/kitinclusivotpta/anaconda3/lib/python3.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/kitinclusivotpta/anaconda3/lib/python3.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (1.25.8)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Installing collected packages: pyasn1, pyasn1-modules, cachetools, rsa, google-auth, protobuf, googleapis-common-protos, google-api-core, google-crc32c, google-resumable-media, google-cloud-core, google-cloud-storage
# Successfully installed cachetools-5.3.0 google-api-core-2.11.0 google-auth-2.16.1 google-cloud-core-2.3.2 google-cloud-storage-2.7.0 google-crc32c-1.5.0 google-resumable-media-2.4.1 googleapis-common-protos-1.58.0 protobuf-4.22.0 pyasn1-0.4.8 pyasn1-modules-0.2.8 rsa-4.9

# %%
import sqlalchemy
import pandas as pd 
from sqlalchemy.orm import sessionmaker
import requests
import json
import pytz
from google.cloud import storage

from datetime import datetime
import datetime
import sqlite3
import json
import pytz
import uuid
import logging

import pandas as pd
# from datetime import datetime
from google.cloud import storage
from flask import Response

# from infrastructure import check_json_schema, get_json_schema_from_gcs
# from authorization import has_authorization

# from parser_config import ConfigParser
# from monitoring import MonitoringApiErrors

TOKEN = "BQBjOSfywA2jvlQvBtOVnG_JS59GhW12v78r_XkzRnmXF2d-5qmAoTi9YMZZhvV7QWCcM3_5HUUAFHyn0d5n5S3Rz6Qdwm7VueI7sgKcXGRkJ3pas3KIYyyqfQFUHvm9R1TruEBht64J3Is4lED9goC5D-Bv9oWcHQv-GEx0TMfil8vAVByKAQDmbwtBo6c20E4jPTw0DA"

# %%
def process_payload(payload_to_process):

    #continuar com base no process_payload to projeto api

# %%
def create_dt_insercao():
    insertion_date = datetime.datetime.utcnow().replace(tzinfo=pytz.UTC)
    insertion_date = insertion_date.astimezone(pytz.timezone("America/Sao_Paulo"))
    return str(insertion_date)[:26]  # cut out the -3:00 timezone information

# %%
headers = {
    "Accept": "application/json",
    "Content-Type": "application/json",
    "Authorization": "Bearer {token}".format(token=TOKEN)
}

today = datetime.datetime.now()
yesterday = today - datetime.timedelta(days=1)
yesterday_unix_timestamp = int(yesterday.timestamp()) * 1000

# r = requests.get('https://api.spotify.com/v1/me/player/recently-played?limit=200&after={time}'.format(time=yesterday_unix_timestamp), headers = headers)
r = requests.get('https://api.spotify.com/v1/me/player/recently-played?limit=50'.format(time=yesterday_unix_timestamp), headers = headers)

data = r.json()


items = data["items"]

# print(len(items))
# print(payloads)

# %%
payload_to_process = items

# %%
payload_to_process
# Out:
# [{'track': {'album': {'album_group': 'single',
#     'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2bkf2PmiVyfCqg2uzIFIqJ'},
#       'href': 'https://api.spotify.com/v1/artists/2bkf2PmiVyfCqg2uzIFIqJ',
#       'id': '2bkf2PmiVyfCqg2uzIFIqJ',
#       'name': 'Jetson',
#       'type': 'artist',
#       'uri': 'spotify:artist:2bkf2PmiVyfCqg2uzIFIqJ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/26tQKjbFsfQzVZ0RPPTsi4'},
#     'href': 'https://api.spotify.com/v1/albums/26tQKjbFsfQzVZ0RPPTsi4',
#     'id': '26tQKjbFsfQzVZ0RPPTsi4',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273aaab648fedf66e93138b7b1c',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02aaab648fedf66e93138b7b1c',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851aaab648fedf66e93138b7b1c',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'lemon water',
#     'release_date': '2018-09-01',
#     'release_date_precision': 'day',
#     'total_tracks': 5,
#     'type': 'album',
#     'uri': 'spotify:album:26tQKjbFsfQzVZ0RPPTsi4'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2bkf2PmiVyfCqg2uzIFIqJ'},
#      'href': 'https://api.spotify.com/v1/artists/2bkf2PmiVyfCqg2uzIFIqJ',
#      'id': '2bkf2PmiVyfCqg2uzIFIqJ',
#      'name': 'Jetson',
#      'type': 'artist',
#      'uri': 'spotify:artist:2bkf2PmiVyfCqg2uzIFIqJ'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/7D6kLgvRHr6DNDavc0LhvI'},
#      'href': 'https://api.spotify.com/v1/artists/7D6kLgvRHr6DNDavc0LhvI',
#      'id': '7D6kLgvRHr6DNDavc0LhvI',
#      'name': 'jhfly',
#      'type': 'artist',
#      'uri': 'spotify:artist:7D6kLgvRHr6DNDavc0LhvI'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XC',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 123000,
#    'explicit': False,
#    'external_ids': {'isrc': 'QM24S1829575'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3RS335Vh4A9M3756pbkzOX'},
#    'href': 'https://api.spotify.com/v1/tracks/3RS335Vh4A9M3756pbkzOX',
#    'id': '3RS335Vh4A9M3756pbkzOX',
#    'is_local': False,
#    'name': 'exposure',
#    'popularity': 12,
#    'preview_url': 'https://p.scdn.co/mp3-preview/111e7235a02227e3fb6ddaed0d21dd6a1b2963fa?cid=774b29d4f13844c495f206cafdad9c86',
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:3RS335Vh4A9M3756pbkzOX'},
#   'played_at': '2023-03-23T21:13:56.154Z',
#   'context': {'type': 'playlist',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/4J5EIe8V8K7jrfQic5OZlg'},
#    'href': 'https://api.spotify.com/v1/playlists/4J5EIe8V8K7jrfQic5OZlg',
#    'uri': 'spotify:playlist:4J5EIe8V8K7jrfQic5OZlg'}},
#  {'track': {'album': {'album_group': 'album',
#     'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6s3PbveUJMvMwZHyQUAPV4'},
#       'href': 'https://api.spotify.com/v1/artists/6s3PbveUJMvMwZHyQUAPV4',
#       'id': '6s3PbveUJMvMwZHyQUAPV4',
#       'name': 'j^p^n',
#       'type': 'artist',
#       'uri': 'spotify:artist:6s3PbveUJMvMwZHyQUAPV4'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6k5ksX8Bwr3gVGq4VtadyG'},
#     'href': 'https://api.spotify.com/v1/albums/6k5ksX8Bwr3gVGq4VtadyG',
#     'id': '6k5ksX8Bwr3gVGq4VtadyG',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273eea8172ccebc3bff952e92bf',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02eea8172ccebc3bff952e92bf',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851eea8172ccebc3bff952e92bf',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Spoils',
#     'release_date': '2016-07-30',
#     'release_date_precision': 'day',
#     'total_tracks': 19,
#     'type': 'album',
#     'uri': 'spotify:album:6k5ksX8Bwr3gVGq4VtadyG'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6s3PbveUJMvMwZHyQUAPV4'},
#      'href': 'https://api.spotify.com/v1/artists/6s3PbveUJMvMwZHyQUAPV4',
#      'id': '6s3PbveUJMvMwZHyQUAPV4',
#      'name': 'j^p^n',
#      'type': 'artist',
#      'uri': 'spotify:artist:6s3PbveUJMvMwZHyQUAPV4'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 104150,
#    'explicit': False,
#    'external_ids': {'isrc': 'QZANL1736410'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7LOR8Rdc5n2EkduOXZeTp6'},
#    'href': 'https://api.spotify.com/v1/tracks/7LOR8Rdc5n2EkduOXZeTp6',
#    'id': '7LOR8Rdc5n2EkduOXZeTp6',
#    'is_local': False,
#    'name': 'Amend',
#    'popularity': 63,
#    'preview_url': 'https://p.scdn.co/mp3-preview/530f27346543f398c281bfd7b5c71253824fe21e?cid=774b29d4f13844c495f206cafdad9c86',
#    'track_number': 13,
#    'type': 'track',
#    'uri': 'spotify:track:7LOR8Rdc5n2EkduOXZeTp6'},
#   'played_at': '2023-03-23T21:11:52.336Z',
#   'context': {'type': 'playlist',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/4J5EIe8V8K7jrfQic5OZlg'},
#    'href': 'https://api.spotify.com/v1/playlists/4J5EIe8V8K7jrfQic5OZlg',
#    'uri': 'spotify:playlist:4J5EIe8V8K7jrfQic5OZlg'}},
#  {'track': {'album': {'album_group': 'album',
#     'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4CWpoyuE7e9NvBkUSTmJfq'},
#       'href': 'https://api.spotify.com/v1/artists/4CWpoyuE7e9NvBkUSTmJfq',
#       'id': '4CWpoyuE7e9NvBkUSTmJfq',
#       'name': 'RŮDE',
#       'type': 'artist',
#       'uri': 'spotify:artist:4CWpoyuE7e9NvBkUSTmJfq'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6STwjBCu3CTEViSxJChKlV'},
#     'href': 'https://api.spotify.com/v1/albums/6STwjBCu3CTEViSxJChKlV',
#     'id': '6STwjBCu3CTEViSxJChKlV',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273097f3d06dd8726a91f526e21',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02097f3d06dd8726a91f526e21',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851097f3d06dd8726a91f526e21',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Eternal Youth',
#     'release_date': '2017-08-07',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:6STwjBCu3CTEViSxJChKlV'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4CWpoyuE7e9NvBkUSTmJfq'},
#      'href': 'https://api.spotify.com/v1/artists/4CWpoyuE7e9NvBkUSTmJfq',
#      'id': '4CWpoyuE7e9NvBkUSTmJfq',
#      'name': 'RŮDE',
#      'type': 'artist',
#      'uri': 'spotify:artist:4CWpoyuE7e9NvBkUSTmJfq'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XC',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 205766,
#    'explicit': False,
#    'external_ids': {'isrc': 'QZ8LD1727702'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0ytvsZOerGzUWfHXVT2Sgy'},
#    'href': 'https://api.spotify.com/v1/tracks/0ytvsZOerGzUWfHXVT2Sgy',
#    'id': '0ytvsZOerGzUWfHXVT2Sgy',
#    'is_local': False,
#    'name': 'Eternal Youth',
#    'popularity': 67,
#    'preview_url': 'https://p.scdn.co/mp3-preview/382362d729212567cb7c9048c89807a5f31a0c19?cid=774b29d4f13844c495f206cafdad9c86',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:0ytvsZOerGzUWfHXVT2Sgy'},
#   'played_at': '2023-03-23T21:10:07.330Z',
#   'context': {'type': 'playlist',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/4J5EIe8V8K7jrfQic5OZlg'},
#    'href': 'https://api.spotify.com/v1/playlists/4J5EIe8V8K7jrfQic5OZlg',
#    'uri': 'spotify:playlist:4J5EIe8V8K7jrfQic5OZlg'}},
#  {'track': {'album': {'album_group': 'single',
#     'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3xuzfrH6RltypjhD15SeFD'},
#       'href': 'https://api.spotify.com/v1/artists/3xuzfrH6RltypjhD15SeFD',
#       'id': '3xuzfrH6RltypjhD15SeFD',
#       'name': 'Shao',
#       'type': 'artist',
#       'uri': 'spotify:artist:3xuzfrH6RltypjhD15SeFD'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7ofexCBC4j1wif00Zrtsjz'},
#     'href': 'https://api.spotify.com/v1/albums/7ofexCBC4j1wif00Zrtsjz',
#     'id': '7ofexCBC4j1wif00Zrtsjz',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2739339073d16d2bf04fe34e02f',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e029339073d16d2bf04fe34e02f',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048519339073d16d2bf04fe34e02f',
#       'width': 64}],
#     'is_playable': True,
#     'name': "Runnin' Up",
#     'release_date': '2018-01-25',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:7ofexCBC4j1wif00Zrtsjz'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3xuzfrH6RltypjhD15SeFD'},
#      'href': 'https://api.spotify.com/v1/artists/3xuzfrH6RltypjhD15SeFD',
#      'id': '3xuzfrH6RltypjhD15SeFD',
#      'name': 'Shao',
#      'type': 'artist',
#      'uri': 'spotify:artist:3xuzfrH6RltypjhD15SeFD'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/01oeaKF2UI2pmIHljhewRN'},
#      'href': 'https://api.spotify.com/v1/artists/01oeaKF2UI2pmIHljhewRN',
#      'id': '01oeaKF2UI2pmIHljhewRN',
#      'name': 'Soudiere',
#      'type': 'artist',
#      'uri': 'spotify:artist:01oeaKF2UI2pmIHljhewRN'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XC',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 236548,
#    'explicit': False,
#    'external_ids': {'isrc': 'QMPKX1804937'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3cjk1SITfuE3fG8XIS0dPS'},
#    'href': 'https://api.spotify.com/v1/tracks/3cjk1SITfuE3fG8XIS0dPS',
#    'id': '3cjk1SITfuE3fG8XIS0dPS',
#    'is_local': False,
#    'name': "Runnin' Up",
#    'popularity': 6,
#    'preview_url': 'https://p.scdn.co/mp3-preview/b4a4b77d382f32a0e9a611c3fa6621f046085e2a?cid=774b29d4f13844c495f206cafdad9c86',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:3cjk1SITfuE3fG8XIS0dPS'},
#   'played_at': '2023-03-23T21:06:41.296Z',
#   'context': {'type': 'playlist',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/4J5EIe8V8K7jrfQic5OZlg'},
#    'href': 'https://api.spotify.com/v1/playlists/4J5EIe8V8K7jrfQic5OZlg',
#    'uri': 'spotify:playlist:4J5EIe8V8K7jrfQic5OZlg'}},
#  {'track': {'album': {'album_group': 'single',
#     'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1anAI9P9iSzc9qzLv6AtHZ'},
#       'href': 'https://api.spotify.com/v1/artists/1anAI9P9iSzc9qzLv6AtHZ',
#       'id': '1anAI9P9iSzc9qzLv6AtHZ',
#       'name': 'Sure Sure',
#       'type': 'artist',
#       'uri': 'spotify:artist:1anAI9P9iSzc9qzLv6AtHZ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4FpWPCgvF7mSQpDZGZgwSU'},
#     'href': 'https://api.spotify.com/v1/albums/4FpWPCgvF7mSQpDZGZgwSU',
#     'id': '4FpWPCgvF7mSQpDZGZgwSU',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273b5629a64cf8516a28c8bba2e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02b5629a64cf8516a28c8bba2e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851b5629a64cf8516a28c8bba2e',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Funky Galileo',
#     'release_date': '2020-03-06',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:4FpWPCgvF7mSQpDZGZgwSU'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1anAI9P9iSzc9qzLv6AtHZ'},
#      'href': 'https://api.spotify.com/v1/artists/1anAI9P9iSzc9qzLv6AtHZ',
#      'id': '1anAI9P9iSzc9qzLv6AtHZ',
#      'name': 'Sure Sure',
#      'type': 'artist',
#      'uri': 'spotify:artist:1anAI9P9iSzc9qzLv6AtHZ'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XC',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 246200,
#    'explicit': False,
#    'external_ids': {'isrc': 'QM24S2001533'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0TAHhMjG17P5pzlSm1sgSl'},
#    'href': 'https://api.spotify.com/v1/tracks/0TAHhMjG17P5pzlSm1sgSl',
#    'id': '0TAHhMjG17P5pzlSm1sgSl',
#    'is_local': False,
#    'name': 'Funky Galileo',
#    'popularity': 53,
#    'preview_url': 'https://p.scdn.co/mp3-preview/b4e04ff161431ebe2d10e6fdcb7a5dfa9865a6ef?cid=774b29d4f13844c495f206cafdad9c86',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:0TAHhMjG17P5pzlSm1sgSl'},
#   'played_at': '2023-03-23T21:02:44.188Z',
#   'context': {'type': 'playlist',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/4J5EIe8V8K7jrfQic5OZlg'},
#    'href': 'https://api.spotify.com/v1/playlists/4J5EIe8V8K7jrfQic5OZlg',
#    'uri': 'spotify:playlist:4J5EIe8V8K7jrfQic5OZlg'}},
#  {'track': {'album': {'album_group': 'album',
#     'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6sa0lNcq7YdXNnQKZHFb0D'},
#       'href': 'https://api.spotify.com/v1/artists/6sa0lNcq7YdXNnQKZHFb0D',
#       'id': '6sa0lNcq7YdXNnQKZHFb0D',
#       'name': 'biosphere',
#       'type': 'artist',
#       'uri': 'spotify:artist:6sa0lNcq7YdXNnQKZHFb0D'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/07sS8e5gtXTt70It4bKe7M'},
#     'href': 'https://api.spotify.com/v1/albums/07sS8e5gtXTt70It4bKe7M',
#     'id': '07sS8e5gtXTt70It4bKe7M',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273bede408f5facfa93ca0e9d39',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02bede408f5facfa93ca0e9d39',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851bede408f5facfa93ca0e9d39',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Rekindle the Past',
#     'release_date': '2018-06-03',
#     'release_date_precision': 'day',
#     'total_tracks': 15,
#     'type': 'album',
#     'uri': 'spotify:album:07sS8e5gtXTt70It4bKe7M'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6sa0lNcq7YdXNnQKZHFb0D'},
#      'href': 'https://api.spotify.com/v1/artists/6sa0lNcq7YdXNnQKZHFb0D',
#      'id': '6sa0lNcq7YdXNnQKZHFb0D',
#      'name': 'biosphere',
#      'type': 'artist',
#      'uri': 'spotify:artist:6sa0lNcq7YdXNnQKZHFb0D'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/5dGqZk0lZFQB6MIus08k8e'},
#      'href': 'https://api.spotify.com/v1/artists/5dGqZk0lZFQB6MIus08k8e',
#      'id': '5dGqZk0lZFQB6MIus08k8e',
#      'name': 'aimless',
#      'type': 'artist',
#      'uri': 'spotify:artist:5dGqZk0lZFQB6MIus08k8e'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XC',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 104096,
#    'explicit': False,
#    'external_ids': {'isrc': 'QZB4J1896377'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7vIoiIZHJcFr1boVZnnuP8'},
#    'href': 'https://api.spotify.com/v1/tracks/7vIoiIZHJcFr1boVZnnuP8',
#    'id': '7vIoiIZHJcFr1boVZnnuP8',
#    'is_local': False,
#    'name': 'the sakuras will cry for you',
#    'popularity': 33,
#    'preview_url': 'https://p.scdn.co/mp3-preview/61ff0ecf7c7b1f15a4af5266389514e9e4e2580c?cid=774b29d4f13844c495f206cafdad9c86',
#    'track_number': 12,
#    'type': 'track',
#    'uri': 'spotify:track:7vIoiIZHJcFr1boVZnnuP8'},
#   'played_at': '2023-03-23T15:54:08.802Z',
#   'context': {'type': 'playlist',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/28I9S8S5rJYsB2OmB6IbN2'},
#    'href': 'https://api.spotify.com/v1/playlists/28I9S8S5rJYsB2OmB6IbN2',
#    'uri': 'spotify:playlist:28I9S8S5rJYsB2OmB6IbN2'}},
#  {'track': {'album': {'album_group': 'album',
#     'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4L0gz16xuM1as1OgYzh1SR'},
#       'href': 'https://api.spotify.com/v1/artists/4L0gz16xuM1as1OgYzh1SR',
#       'id': '4L0gz16xuM1as1OgYzh1SR',
#       'name': 'Kensuke Ushio',
#       'type': 'artist',
#       'uri': 'spotify:artist:4L0gz16xuM1as1OgYzh1SR'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3WlmFFtmePwfhN9pQdVJ5v'},
#     'href': 'https://api.spotify.com/v1/albums/3WlmFFtmePwfhN9pQdVJ5v',
#     'id': '3WlmFFtmePwfhN9pQdVJ5v',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273598142e7eef56d543ec8f922',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02598142e7eef56d543ec8f922',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851598142e7eef56d543ec8f922',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'A Shape of Light "A Silent Voice the Movie" Original Soundtrack',
#     'release_date': '2016-09-14',
#     'release_date_precision': 'day',
#     'total_tracks': 61,
#     'type': 'album',
#     'uri': 'spotify:album:3WlmFFtmePwfhN9pQdVJ5v'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4L0gz16xuM1as1OgYzh1SR'},
#      'href': 'https://api.spotify.com/v1/artists/4L0gz16xuM1as1OgYzh1SR',
#      'id': '4L0gz16xuM1as1OgYzh1SR',
#      'name': 'Kensuke Ushio',
#      'type': 'artist',
#      'uri': 'spotify:artist:4L0gz16xuM1as1OgYzh1SR'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 95880,
#    'explicit': False,
#    'external_ids': {'isrc': 'JPPC01601659'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4vpm7wjfkwcqlZhX5Cnhqt'},
#    'href': 'https://api.spotify.com/v1/tracks/4vpm7wjfkwcqlZhX5Cnhqt',
#    'id': '4vpm7wjfkwcqlZhX5Cnhqt',
#    'is_local': False,
#    'name': 'flw',
#    'popularity': 36,
#    'preview_url': 'https://p.scdn.co/mp3-preview/c6a816efacef82a2974ea9ad6196ca78842f78f1?cid=774b29d4f13844c495f206cafdad9c86',
#    'track_number': 16,
#    'type': 'track',
#    'uri': 'spotify:track:4vpm7wjfkwcqlZhX5Cnhqt'},
#   'played_at': '2023-03-23T15:43:23.549Z',
#   'context': {'type': 'playlist',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/28I9S8S5rJYsB2OmB6IbN2'},
#    'href': 'https://api.spotify.com/v1/playlists/28I9S8S5rJYsB2OmB6IbN2',
#    'uri': 'spotify:playlist:28I9S8S5rJYsB2OmB6IbN2'}},
#  {'track': {'album': {'album_group': 'album',
#     'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/55ZGP7wiI7sIfU36CTeBzT'},
#       'href': 'https://api.spotify.com/v1/artists/55ZGP7wiI7sIfU36CTeBzT',
#       'id': '55ZGP7wiI7sIfU36CTeBzT',
#       'name': 'sad boy with a laptop',
#       'type': 'artist',
#       'uri': 'spotify:artist:55ZGP7wiI7sIfU36CTeBzT'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4ahEYxAEr2OGrDLc28iReq'},
#     'href': 'https://api.spotify.com/v1/albums/4ahEYxAEr2OGrDLc28iReq',
#     'id': '4ahEYxAEr2OGrDLc28iReq',
#     'images': [{'height': 640,
# ...
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 87428,
#    'explicit': False,
#    'external_ids': {'isrc': 'USANG2116517'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4eiAkiGZr0w126YOMAtkxz'},
#    'href': 'https://api.spotify.com/v1/tracks/4eiAkiGZr0w126YOMAtkxz',
#    'id': '4eiAkiGZr0w126YOMAtkxz',
#    'is_local': False,
#    'name': 'Winter Warmth',
#    'popularity': 54,
#    'preview_url': 'https://p.scdn.co/mp3-preview/6ec969f0f3f72e1afcc486e2ac88f6556282ee29?cid=774b29d4f13844c495f206cafdad9c86',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:4eiAkiGZr0w126YOMAtkxz'},
#   'played_at': '2023-03-23T14:20:24.311Z',
#   'context': {'type': 'playlist',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/28I9S8S5rJYsB2OmB6IbN2'},
#    'href': 'https://api.spotify.com/v1/playlists/28I9S8S5rJYsB2OmB6IbN2',
#    'uri': 'spotify:playlist:28I9S8S5rJYsB2OmB6IbN2'}},
#  {'track': {'album': {'album_group': 'album',
#     'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6CY7WNJfd5uZclcS3WeEjx'},
#       'href': 'https://api.spotify.com/v1/artists/6CY7WNJfd5uZclcS3WeEjx',
#       'id': '6CY7WNJfd5uZclcS3WeEjx',
#       'name': 'Yu-Peng Chen',
#       'type': 'artist',
#       'uri': 'spotify:artist:6CY7WNJfd5uZclcS3WeEjx'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2YvlK6lKiKVjXxsjvNbnqg'},
#       'href': 'https://api.spotify.com/v1/artists/2YvlK6lKiKVjXxsjvNbnqg',
#       'id': '2YvlK6lKiKVjXxsjvNbnqg',
#       'name': 'HOYO-MiX',
#       'type': 'artist',
#       'uri': 'spotify:artist:2YvlK6lKiKVjXxsjvNbnqg'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/22jmHd52fUk6hDe8S3Et0T'},
#     'href': 'https://api.spotify.com/v1/albums/22jmHd52fUk6hDe8S3Et0T',
#     'id': '22jmHd52fUk6hDe8S3Et0T',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273ae37e6f73804085bf53b23c7',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02ae37e6f73804085bf53b23c7',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851ae37e6f73804085bf53b23c7',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Genshin Impact - Jade Moon Upon a Sea of Clouds (Original Game Soundtrack)',
#     'release_date': '2020-11-06',
#     'release_date_precision': 'day',
#     'total_tracks': 69,
#     'type': 'album',
#     'uri': 'spotify:album:22jmHd52fUk6hDe8S3Et0T'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6CY7WNJfd5uZclcS3WeEjx'},
#      'href': 'https://api.spotify.com/v1/artists/6CY7WNJfd5uZclcS3WeEjx',
#      'id': '6CY7WNJfd5uZclcS3WeEjx',
#      'name': 'Yu-Peng Chen',
#      'type': 'artist',
#      'uri': 'spotify:artist:6CY7WNJfd5uZclcS3WeEjx'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/2YvlK6lKiKVjXxsjvNbnqg'},
#      'href': 'https://api.spotify.com/v1/artists/2YvlK6lKiKVjXxsjvNbnqg',
#      'id': '2YvlK6lKiKVjXxsjvNbnqg',
#      'name': 'HOYO-MiX',
#      'type': 'artist',
#      'uri': 'spotify:artist:2YvlK6lKiKVjXxsjvNbnqg'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 82927,
#    'explicit': False,
#    'external_ids': {'isrc': 'FR26V2016970'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2ceLH0wzOEY4mCBC3xAPpt'},
#    'href': 'https://api.spotify.com/v1/tracks/2ceLH0wzOEY4mCBC3xAPpt',
#    'id': '2ceLH0wzOEY4mCBC3xAPpt',
#    'is_local': False,
#    'name': 'Clear Sky over Liyue',
#    'popularity': 48,
#    'preview_url': 'https://p.scdn.co/mp3-preview/f527e9d9bfe489910fb8e21314c9d258c7acceae?cid=774b29d4f13844c495f206cafdad9c86',
#    'track_number': 8,
#    'type': 'track',
#    'uri': 'spotify:track:2ceLH0wzOEY4mCBC3xAPpt'},
#   'played_at': '2023-03-23T14:18:56.981Z',
#   'context': {'type': 'playlist',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/28I9S8S5rJYsB2OmB6IbN2'},
#    'href': 'https://api.spotify.com/v1/playlists/28I9S8S5rJYsB2OmB6IbN2',
#    'uri': 'spotify:playlist:28I9S8S5rJYsB2OmB6IbN2'}},
#  {'track': {'album': {'album_group': 'album',
#     'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2hR4h1Cao2ueuI7Cx9c7V8'},
#       'href': 'https://api.spotify.com/v1/artists/2hR4h1Cao2ueuI7Cx9c7V8',
#       'id': '2hR4h1Cao2ueuI7Cx9c7V8',
#       'name': 'Cavetown',
#       'type': 'artist',
#       'uri': 'spotify:artist:2hR4h1Cao2ueuI7Cx9c7V8'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CD',
#      'CG',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'ET',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IQ',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'LY',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TJ',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VE',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5rvA7Pth9X8PFp5jHqFl3V'},
#     'href': 'https://api.spotify.com/v1/albums/5rvA7Pth9X8PFp5jHqFl3V',
#     'id': '5rvA7Pth9X8PFp5jHqFl3V',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273a29186e92ad38b89ae1611ea',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02a29186e92ad38b89ae1611ea',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851a29186e92ad38b89ae1611ea',
#       'width': 64}],
#     'is_playable': True,
#     'name': 'Lemon Boy',
#     'release_date': '2018-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:5rvA7Pth9X8PFp5jHqFl3V'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2hR4h1Cao2ueuI7Cx9c7V8'},
#      'href': 'https://api.spotify.com/v1/artists/2hR4h1Cao2ueuI7Cx9c7V8',
#      'id': '2hR4h1Cao2ueuI7Cx9c7V8',
#      'name': 'Cavetown',
#      'type': 'artist',
#      'uri': 'spotify:artist:2hR4h1Cao2ueuI7Cx9c7V8'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'LB',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'IQ',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XC',
#     'XK'],
#    'disc_number': 1,
#    'duration_ms': 272902,
#    'explicit': False,
#    'external_ids': {'isrc': 'USCGH1805100'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3Yvk0ZLxMlt6ioasvdN6vB'},
#    'href': 'https://api.spotify.com/v1/tracks/3Yvk0ZLxMlt6ioasvdN6vB',
#    'id': '3Yvk0ZLxMlt6ioasvdN6vB',
#    'is_local': False,
#    'name': 'Lemon Boy',
#    'popularity': 65,
#    'preview_url': 'https://p.scdn.co/mp3-preview/1afca0db8b7b83784384b3086e7f216d4dbfae0b?cid=774b29d4f13844c495f206cafdad9c86',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:3Yvk0ZLxMlt6ioasvdN6vB'},
#   'played_at': '2023-03-23T14:17:34.170Z',
#   'context': {'type': 'playlist',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/28I9S8S5rJYsB2OmB6IbN2'},
#    'href': 'https://api.spotify.com/v1/playlists/28I9S8S5rJYsB2OmB6IbN2',
#    'uri': 'spotify:playlist:28I9S8S5rJYsB2OmB6IbN2'}}]

# %%
dt_insercao = create_dt_insercao()
df = pd.DataFrame()
df = df.assign(payload=payload_to_process)
df['played_at'] = df['payload'].map(lambda x: x['played_at'])
df['context'] = df['payload'].map(lambda x: x['context'])
df['partition'] = dt_insercao[:13]

# %%
df
# Out:
#                                               payload  \
# 0   {'track': {'album': {'album_group': 'single', ...
# 1   {'track': {'album': {'album_group': 'album', '...
# 2   {'track': {'album': {'album_group': 'album', '...
# 3   {'track': {'album': {'album_group': 'single', ...
# 4   {'track': {'album': {'album_group': 'single', ...
# 5   {'track': {'album': {'album_group': 'album', '...
# 6   {'track': {'album': {'album_group': 'album', '...
# 7   {'track': {'album': {'album_group': 'album', '...
# 8   {'track': {'album': {'album_group': 'album', '...
# 9   {'track': {'album': {'album_group': 'album', '...
# 10  {'track': {'album': {'album_group': 'single', ...
# 11  {'track': {'album': {'album_group': 'album', '...
# 12  {'track': {'album': {'album_group': 'single', ...
# 13  {'track': {'album': {'album_group': 'single', ...
# 14  {'track': {'album': {'album_group': 'single', ...
# 15  {'track': {'album': {'album_group': 'album', '...
# 16  {'track': {'album': {'album_group': 'album', '...
# 17  {'track': {'album': {'album_group': 'single', ...
# 18  {'track': {'album': {'album_group': 'single', ...
# 19  {'track': {'album': {'album_group': 'album', '...
# 20  {'track': {'album': {'album_group': 'album', '...
# 21  {'track': {'album': {'album_group': 'album', '...
# 22  {'track': {'album': {'album_group': 'album', '...
# 23  {'track': {'album': {'album_group': 'album', '...
# 24  {'track': {'album': {'album_group': 'single', ...
# 25  {'track': {'album': {'album_group': 'single', ...
# 26  {'track': {'album': {'album_group': 'album', '...
# 27  {'track': {'album': {'album_group': 'album', '...
# 28  {'track': {'album': {'album_group': 'single', ...
# 29  {'track': {'album': {'album_group': 'album', '...
# 30  {'track': {'album': {'album_group': 'single', ...
# 31  {'track': {'album': {'album_group': 'album', '...
# 32  {'track': {'album': {'album_group': 'single', ...
# 33  {'track': {'album': {'album_group': 'single', ...
# 34  {'track': {'album': {'album_group': 'single', ...
# 35  {'track': {'album': {'album_group': 'compilati...
# 36  {'track': {'album': {'album_group': 'album', '...
# 37  {'track': {'album': {'album_group': 'album', '...
# 38  {'track': {'album': {'album_group': 'single', ...
# 39  {'track': {'album': {'album_group': 'single', ...
# 40  {'track': {'album': {'album_group': 'album', '...
# 41  {'track': {'album': {'album_group': 'album', '...
# 42  {'track': {'album': {'album_group': 'single', ...
# 43  {'track': {'album': {'album_group': 'album', '...
# 44  {'track': {'album': {'album_group': 'single', ...
# 45  {'track': {'album': {'album_group': 'album', '...
# 46  {'track': {'album': {'album_group': 'album', '...
# 47  {'track': {'album': {'album_group': 'single', ...
# 48  {'track': {'album': {'album_group': 'album', '...
# 49  {'track': {'album': {'album_group': 'album', '...
#
#                    played_at  \
# 0   2023-03-23T21:13:56.154Z
# 1   2023-03-23T21:11:52.336Z
# 2   2023-03-23T21:10:07.330Z
# 3   2023-03-23T21:06:41.296Z
# 4   2023-03-23T21:02:44.188Z
# 5   2023-03-23T15:54:08.802Z
# 6   2023-03-23T15:43:23.549Z
# 7   2023-03-23T15:41:47.795Z
# 8   2023-03-23T15:39:42.622Z
# 9   2023-03-23T15:37:10.741Z
# 10  2023-03-23T15:34:25.921Z
# 11  2023-03-23T15:32:17.034Z
# 12  2023-03-23T15:30:19.875Z
# 13  2023-03-23T15:29:12.115Z
# 14  2023-03-23T15:26:44.164Z
# 15  2023-03-23T15:24:32.489Z
# 16  2023-03-23T15:21:34.481Z
# 17  2023-03-23T15:19:40.025Z
# 18  2023-03-23T15:17:46.146Z
# 19  2023-03-23T15:15:35.709Z
# 20  2023-03-23T15:13:26.892Z
# 21  2023-03-23T15:12:14.813Z
# 22  2023-03-23T15:10:07.905Z
# 23  2023-03-23T15:08:04.580Z
# 24  2023-03-23T15:05:58.682Z
# 25  2023-03-23T15:03:44.168Z
# 26  2023-03-23T15:00:57.189Z
# 27  2023-03-23T14:59:38.686Z
# 28  2023-03-23T14:58:01.528Z
# 29  2023-03-23T14:56:40.923Z
# 30  2023-03-23T14:53:39.835Z
# 31  2023-03-23T14:52:06.618Z
# 32  2023-03-23T14:51:09.233Z
# 33  2023-03-23T14:50:00.339Z
# 34  2023-03-23T14:47:44.492Z
# 35  2023-03-23T14:45:45.462Z
# 36  2023-03-23T14:43:52.481Z
# 37  2023-03-23T14:40:34.244Z
# 38  2023-03-23T14:39:15.906Z
# 39  2023-03-23T14:37:01.908Z
# 40  2023-03-23T14:34:29.744Z
# 41  2023-03-23T14:33:39.353Z
# 42  2023-03-23T14:31:29.200Z
# 43  2023-03-23T14:29:41.103Z
# 44  2023-03-23T14:26:52.089Z
# 45  2023-03-23T14:25:13.891Z
# 46  2023-03-23T14:22:39.825Z
# 47  2023-03-23T14:20:24.311Z
# 48  2023-03-23T14:18:56.981Z
# 49  2023-03-23T14:17:34.170Z
#
#                                               context      partition
# 0   {'type': 'playlist', 'external_urls': {'spotif...  2023-03-23 23
# 1   {'type': 'playlist', 'external_urls': {'spotif...  2023-03-23 23
# 2   {'type': 'playlist', 'external_urls': {'spotif...  2023-03-23 23
# 3   {'type': 'playlist', 'external_urls': {'spotif...  2023-03-23 23
# 4   {'type': 'playlist', 'external_urls': {'spotif...  2023-03-23 23
# 5   {'type': 'playlist', 'external_urls': {'spotif...  2023-03-23 23
# 6   {'type': 'playlist', 'external_urls': {'spotif...  2023-03-23 23
# 7   {'type': 'playlist', 'external_urls': {'spotif...  2023-03-23 23
# 8   {'type': 'playlist', 'external_urls': {'spotif...  2023-03-23 23
# 9   {'type': 'playlist', 'external_urls': {'spotif...  2023-03-23 23
# 10  {'type': 'playlist', 'external_urls': {'spotif...  2023-03-23 23
# 11  {'type': 'playlist', 'external_urls': {'spotif...  2023-03-23 23
# 12  {'type': 'playlist', 'external_urls': {'spotif...  2023-03-23 23
# 13  {'type': 'playlist', 'external_urls': {'spotif...  2023-03-23 23
# 14  {'type': 'playlist', 'external_urls': {'spotif...  2023-03-23 23
# 15  {'type': 'playlist', 'external_urls': {'spotif...  2023-03-23 23
# 16  {'type': 'playlist', 'external_urls': {'spotif...  2023-03-23 23
# 17  {'type': 'playlist', 'external_urls': {'spotif...  2023-03-23 23
# 18  {'type': 'playlist', 'external_urls': {'spotif...  2023-03-23 23
# 19  {'type': 'playlist', 'external_urls': {'spotif...  2023-03-23 23
# 20  {'type': 'playlist', 'external_urls': {'spotif...  2023-03-23 23
# 21  {'type': 'playlist', 'external_urls': {'spotif...  2023-03-23 23
# 22  {'type': 'playlist', 'external_urls': {'spotif...  2023-03-23 23
# 23  {'type': 'playlist', 'external_urls': {'spotif...  2023-03-23 23
# 24  {'type': 'playlist', 'external_urls': {'spotif...  2023-03-23 23
# 25  {'type': 'playlist', 'external_urls': {'spotif...  2023-03-23 23
# 26  {'type': 'playlist', 'external_urls': {'spotif...  2023-03-23 23
# 27  {'type': 'playlist', 'external_urls': {'spotif...  2023-03-23 23
# 28  {'type': 'playlist', 'external_urls': {'spotif...  2023-03-23 23
# 29  {'type': 'playlist', 'external_urls': {'spotif...  2023-03-23 23
# 30  {'type': 'playlist', 'external_urls': {'spotif...  2023-03-23 23
# 31  {'type': 'playlist', 'external_urls': {'spotif...  2023-03-23 23
# 32  {'type': 'playlist', 'external_urls': {'spotif...  2023-03-23 23
# 33  {'type': 'playlist', 'external_urls': {'spotif...  2023-03-23 23
# 34  {'type': 'playlist', 'external_urls': {'spotif...  2023-03-23 23
# 35  {'type': 'playlist', 'external_urls': {'spotif...  2023-03-23 23
# 36  {'type': 'playlist', 'external_urls': {'spotif...  2023-03-23 23
# 37  {'type': 'playlist', 'external_urls': {'spotif...  2023-03-23 23
# 38  {'type': 'playlist', 'external_urls': {'spotif...  2023-03-23 23
# 39  {'type': 'playlist', 'external_urls': {'spotif...  2023-03-23 23
# 40  {'type': 'playlist', 'external_urls': {'spotif...  2023-03-23 23
# 41  {'type': 'playlist', 'external_urls': {'spotif...  2023-03-23 23
# 42  {'type': 'playlist', 'external_urls': {'spotif...  2023-03-23 23
# 43  {'type': 'playlist', 'external_urls': {'spotif...  2023-03-23 23
# 44  {'type': 'playlist', 'external_urls': {'spotif...  2023-03-23 23
# 45  {'type': 'playlist', 'external_urls': {'spotif...  2023-03-23 23
# 46  {'type': 'playlist', 'external_urls': {'spotif...  2023-03-23 23
# 47  {'type': 'playlist', 'external_urls': {'spotif...  2023-03-23 23
# 48  {'type': 'playlist', 'external_urls': {'spotif...  2023-03-23 23
# 49  {'type': 'playlist', 'external_urls': {'spotif...  2023-03-23 23

# %%
parts = df['partition'].drop_duplicates().to_list()

# %%
parts
# Out:
# ['2023-03-23 23']

# %%
parts.to_list()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-14c6d95463c1> in <module>
# ----> 1 parts.to_list()
#
# AttributeError: 'list' object has no attribute 'to_list'

# %%
client = storage.Client("spotify-wrapped")
bucket = client.bucket("spotify-raw")

# %%
import load_json
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-13-78633fc85b37> in <module>
# ----> 1 import load_json
#
# ModuleNotFoundError: No module named 'load_json'

# %%
from google.cloud import storage
from google.oauth2.service_account import Credentials

creds = Credentials.from_service_account_file("/home/kitinclusivotpta/spotify-wrapped-377220-112f18f655f4.json")
client = storage.Client(credentials=creds, project="spotify-wrapped")
bucket = client.bucket("spotify-raw")

# %%
# parts = df['partition'].drop_duplicates().to_list()
    
table_name = "songs-raw"

for part in parts:
    year_part = part[:4]
    month_part = part[5:7]
    day_part = part[8:10]
    hour_part = part[11:13]
    blob_name = f'{table_name}/"test"'
    bucket.blob(blob_name).upload_from_string(df.to_json(orient='records', lines=True), 'application/json')

response_text = {'statusCode': 201, 'body': 'Created'}

logging.info("Saved to bucket")
# return Response(f'{response_text}', status=201, mimetype='application/json')

# %%
# !pip install spotipy
# Out:
# Collecting spotipy
#   Downloading spotipy-2.22.1-py3-none-any.whl (28 kB)
# Collecting redis>=3.5.3
#   Downloading redis-4.5.3-py3-none-any.whl (238 kB)
#      |████████████████████████████████| 238 kB 6.5 MB/s eta 0:00:01
# Collecting requests>=2.25.0
#   Using cached requests-2.28.2-py3-none-any.whl (62 kB)
# Collecting urllib3>=1.26.0
#   Downloading urllib3-1.26.15-py2.py3-none-any.whl (140 kB)
#      |████████████████████████████████| 140 kB 41.3 MB/s eta 0:00:01
# Collecting six>=1.15.0
#   Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting typing-extensions; python_version < "3.8"
#   Downloading typing_extensions-4.5.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: importlib-metadata>=1.0; python_version < "3.8" in /home/kitinclusivotpta/anaconda3/lib/python3.7/site-packages (from redis>=3.5.3->spotipy) (1.5.0)
# Collecting async-timeout>=4.0.2; python_version < "3.11"
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: idna<4,>=2.5 in /home/kitinclusivotpta/anaconda3/lib/python3.7/site-packages (from requests>=2.25.0->spotipy) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /home/kitinclusivotpta/anaconda3/lib/python3.7/site-packages (from requests>=2.25.0->spotipy) (2019.11.28)
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.1.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (171 kB)
#      |████████████████████████████████| 171 kB 44.5 MB/s eta 0:00:01
# Requirement already satisfied: zipp>=0.5 in /home/kitinclusivotpta/anaconda3/lib/python3.7/site-packages (from importlib-metadata>=1.0; python_version < "3.8"->redis>=3.5.3->spotipy) (2.2.0)
# ERROR: pytest-astropy 0.8.0 requires pytest-cov>=2.0, which is not installed.
# ERROR: pytest-astropy 0.8.0 requires pytest-filter-subpackage>=0.1, which is not installed.
# ERROR: astroid 2.3.3 requires typed-ast<1.5,>=1.4.0; implementation_name == "cpython" and python_version < "3.8", which is not installed.
# Installing collected packages: typing-extensions, async-timeout, redis, urllib3, charset-normalizer, requests, six, spotipy
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.25.8
#     Uninstalling urllib3-1.25.8:
#       Successfully uninstalled urllib3-1.25.8
#   Attempting uninstall: requests
#     Found existing installation: requests 2.22.0
#     Uninstalling requests-2.22.0:
#       Successfully uninstalled requests-2.22.0
#   Attempting uninstall: six
#     Found existing installation: six 1.14.0
#     Uninstalling six-1.14.0:
#       Successfully uninstalled six-1.14.0
# Successfully installed async-timeout-4.0.2 charset-normalizer-3.1.0 redis-4.5.3 requests-2.28.2 six-1.16.0 spotipy-2.22.1 typing-extensions-4.5.0 urllib3-1.26.15

# %%
import sqlalchemy
import pandas as pd 
from sqlalchemy.orm import sessionmaker
import requests
import json
import pytz
from google.cloud import storage
from google.oauth2.service_account import Credentials

from datetime import datetime
import datetime
import sqlite3
import json
import pytz
import uuid
import logging

import pandas as pd
# from datetime import datetime
from google.cloud import storage
from flask import Response
import base64
import json 
from requests import post

client_id = "b834e40874cd4cbaa48507238730ce31"
client_secret = "f0a7d5f87cc24ac9aa7647553b7c32b8"

creds = Credentials.from_service_account_file("/home/kitinclusivotpta/spotify-wrapped-377220-112f18f655f4.json")
client = storage.Client(credentials=creds, project="spotify-wrapped")
bucket = client.bucket("spotify-raw")

def get_token():
    auth_string = client_id + ":" + client_secret
    auth_bytes = auth_string.encode("utf-8")
    auth_base64 = str(base64.b64encode(auth_bytes), "utf-8")
    
    
    url = "https://accounts.spotify.com/api/token"
    headers = {
        "Authorization": "Basic " + auth_base64,
        "Content-Type": "application/x-www-form-urlencoded"
    }
    data = {"grant_type": "client_credentials", "scope": "user-library-read user-read-recently-played"}
    result = post(url, headers=headers, data=data)
    json_result = json.loads(result.content)
    token = json_result["access_token"]
    return token

def create_dt_insercao():
    insertion_date = datetime.datetime.utcnow().replace(tzinfo=pytz.UTC)
    insertion_date = insertion_date.astimezone(pytz.timezone("America/Sao_Paulo"))
    return str(insertion_date)[:26]  # cut out the -3:00 timezone information

def process_payload(payload_to_process):
    dt_insercao = create_dt_insercao()
    df = pd.DataFrame()
    df = df.assign(payload=payload_to_process)
    df['played_at'] = df['payload'].map(lambda x: x['played_at'])
    df['context'] = df['payload'].map(lambda x: x['context'])
    df['partition'] = dt_insercao[:13]
    return df
    
def create_dt_insercao():
    insertion_date = datetime.datetime.utcnow().replace(tzinfo=pytz.UTC)
    insertion_date = insertion_date.astimezone(pytz.timezone("America/Sao_Paulo"))
    return str(insertion_date)[:26]  # cut out the -3:00 timezone information

if __name__ == "__main__":
    
    TOKEN = get_token()
    print(TOKEN)
    headers = {
        "Accept": "application/json",
        "Content-Type": "application/json",
        "Authorization": "Bearer {token}".format(token=TOKEN)
    }

    today = datetime.datetime.now()
    yesterday = today - datetime.timedelta(days=1)
    yesterday_unix_timestamp = int(yesterday.timestamp()) * 1000

    # r = requests.get('https://api.spotify.com/v1/me/player/recently-played?limit=200&after={time}'.format(time=yesterday_unix_timestamp), headers = headers)
    r = requests.get('https://api.spotify.com/v1/me/player/recently-played?limit=50&scope=user-read-recently-played'.format(time=yesterday_unix_timestamp), headers=headers)

    data = r.json()
    print(data)

    items = data["items"]

    # print(len(items))
    # print(payloads)

    payload_to_process = items

    df = process_payload(payload_to_process)
    parts = df['partition'].drop_duplicates().to_list()

    table_name = "songs-raw"

    for part in parts:
        year_part = part[:4]
        month_part = part[5:7]
        day_part = part[8:10]
        hour_part = part[11:13]
        blob_name = f'{table_name}/"test"'
        bucket.blob(blob_name).upload_from_string(df.to_json(orient='records', lines=True), 'application/json')

    response_text = {'statusCode': 201, 'body': 'Created'}

    logging.info("Saved to bucket")
# Out:
# BQBarzf9x1ZeypZZ1Z2djcoZvthWG6bHhPDl-RXFCfDPQGp-VnJnjMwk5w3JUH3xwEA9wO1qzfaJiYIwJREerAyv109_2v6jCJdOgV51ws7OiAPr5VvENkUFOEW8J81LMmxR
# {'error': {'status': 500, 'message': 'Server error.'}}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-566ec806c5db> in <module>
#      87     print(data)
#      88
# ---> 89     items = data["items"]
#      90
#      91     # print(len(items))
#
# KeyError: 'items'

# %%
# !pip install cred
# Out:
# Collecting cred
#   Downloading cred-0.1-py3-none-any.whl (4.0 kB)
# Collecting pyperclip>=1.8.2
#   Downloading pyperclip-1.8.2.tar.gz (20 kB)
# Building wheels for collected packages: pyperclip
#   Building wheel for pyperclip (setup.py) ... done
#   Created wheel for pyperclip: filename=pyperclip-1.8.2-py3-none-any.whl size=11107 sha256=9117a6e1f159a5821f1093aaec74dcf1ff154bfef2a8e53008660c0a52a781c0
#   Stored in directory: /home/kitinclusivotpta/.cache/pip/wheels/9f/18/84/8f69f8b08169c7bae2dde6bd7daf0c19fca8c8e500ee620a28
# Successfully built pyperclip
# Installing collected packages: pyperclip, cred
# Successfully installed cred-0.1 pyperclip-1.8.2

# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth

scope = "user-read-recently-played"
client_id = "b834e40874cd4cbaa48507238730ce31"
client_secret = "f0a7d5f87cc24ac9aa7647553b7c32b8"
redirect_url="https://www.postman.com/oauth2/callback"
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id=client_id, client_secret= client_secret, redirect_uri=redirect_url, scope=scope))

results = sp.current_user_recently_played()
for idx, item in enumerate(results['items']):
    track = item['track']
    print(idx, track['artists'][0]['name'], " – ", track['name'])
